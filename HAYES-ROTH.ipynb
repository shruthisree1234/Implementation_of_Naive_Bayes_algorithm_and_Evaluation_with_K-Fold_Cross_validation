# %%
import numpy as np
import pandas as pd
from math import sqrt,exp,pi,log
from random import randrange

# %%
df1 = pd.read_csv(r"C:\Users\shruthi sree\Downloads\hayes-roth.data",header = None)
df1.to_csv(r"C:\Users\shruthi sree\Desktop\ML_PA_1001933428\hayes-roth.csv",header=["name","hobby","age","educational-level","marital-status","class"])
df1 = pd.read_csv(r"C:\Users\shruthi sree\Desktop\ML_PA_1001933428\hayes-roth.csv")
data1 = df1.iloc[:,:].values

from sklearn.preprocessing import LabelEncoder  
lab = LabelEncoder()
for i in range(len(data1[0])):
    data1[:,i]=lab.fit_transform(data1[:,i])   
ulist = np.unique(data1[:,-1])

# %%
def eval_algo(data1, nfolds):
    folds = crossval_split(data1, nfolds)
    scores = list()
    i=0
    while i < (len(folds)):
        train_set=list()
        j=0
        while j< (len(folds)):
            if i!=j:
                train_set.append(folds[j])
            j+= 1
        train_set=list(folds)
        train_set = sum(train_set, [])
        test_set = list()
        for row in folds[i]:
            row1 = list(row)
            test_set.append(row1)
            row1[-1] = None
        pred = naive_bayes(train_set, test_set)
        act = [row[-1] for row in folds[i]]
        accuracy = acc_metric(act, pred)
        scores.append(accuracy)
        i+=1
    return scores

# %%
def crossval_split(data1, nfolds):
    data_split = list()
    data_copy = list(data1)
    fold_size = int(len(data1) / nfolds)
    for i in range(nfolds):
        fold = list()
        while len(fold) < fold_size:
            index = randrange(len(data_copy))
            fold.append(data_copy.pop(index))
        data_split.append(fold)
    return data_split

# %%
def naive_bayes(train, test):
    print(train)
    summarize = summarize_by_class(train)
    predictions = list()
    for row in test:
        output = predict(summarize, row)
        predictions.append(output)
    return(predictions)

# %%
def summarize_by_class(data1):
    separated = split_by_class(data1,ulist)
    summaries = dict()
    for value, rows in separated.items():
        summaries[value] = summarize(rows)
    return summaries

# %%
def split_by_class(data1,ulist):
    slist=dict()
    for a in ulist:
        slist[a]=list()
    a=0
    while a < (len(data1)):
        vector=data1[a]
        value=vector[-1]
        slist[value].append(vector)
        a+=1
    return slist

# %%
def summarize(data1):
    summaries = [(mean(column), std_dev(column), len(column)) for column in zip(*data1)]
    del(summaries[-1])
    return summaries

# %%
def predict(summaries, row):
    prob = calculate_class_probabilities(summaries, row)
    best_label, best_prob = None, -1
    for value, probability in prob.items():
        if best_label is None or probability > best_prob:
            best_prob = probability
            best_label = value
    return best_label

# %%
def calculate_probability(x, mean, stddev):
    if stddev==0.0 or mean==0.0:
        return 0.0
    exponent = exp(-((x-mean)**2 / (2 * stddev**2 )))
    return (1 / (sqrt(2 * pi) * stddev)) * exponent

# %%
def calculate_class_probabilities(summaries, row):
    total_rows = sum([summaries[label][0][2] for label in summaries])
    prob = dict()
    for value, class_summaries in summaries.items():
        prob[value] = summaries[value][0][2]/float(total_rows)
        for i in range(len(class_summaries)):
            mean, stddev, _ = class_summaries[i]
            prob[value] *= calculate_probability(row[i], mean, stddev)
    return prob

# %%
def mean(num):
    return sum(num)/float(len(num))
def std_dev(num):
    avg=mean(num)
    var = sum([(x-avg)**2 for x in num]) / float(len(num)-1) 
    return sqrt(var)

# %%
def acc_metric(act, pred):
    crct = 0
    a=0
    while a<(len(act)):
        if act[a] == pred[a]:
            crct += 1
        a+=1
    return crct / float(len(act)) * 100.0

# %%
scores=eval_algo(data1,10)
print('Scores: %s' % scores)
print('Mean Accuracy: %.4f%%' % (sum(scores)/float(len(scores))))
# Out:
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# [array([ 8, 35,  1,  1,  0,  0,  0], dtype=int64), array([54, 95,  0,  0,  0,  1,  0], dtype=int64), array([47, 53,  0,  0,  0,  1,  0], dtype=int64), array([ 57, 122,   1,   0,   1,   0,   0], dtype=int64), array([40, 83,  1,  1,  1,  0,  1], dtype=int64), array([91, 64,  1,  2,  1,  2,  1], dtype=int64), array([ 70, 101,   2,   0,   3,   1,   2], dtype=int64), array([94, 58,  0,  0,  0,  1,  0], dtype=int64), array([108,  54,   0,   3,   1,   2,   2], dtype=int64), array([83, 34,  0,  1,  0,  2,  0], dtype=int64), array([131,   8,   2,   0,   0,   1,   0], dtype=int64), array([56, 69,  1,  1,  1,  0,  1], dtype=int64), array([118, 123,   2,   2,   1,   1,   1], dtype=int64), array([101,  96,   1,   0,   2,   0,   0], dtype=int64), array([109, 102,   1,   1,   0,   0,   0], dtype=int64), array([ 73, 118,   2,   0,   2,   1,   0], dtype=int64), array([38, 81,  0,  1,  0,  1,  1], dtype=int64), array([87, 30,  2,  2,  1,  0,  1], dtype=int64), array([84, 26,  0,  3,  3,  0,  2], dtype=int64), array([ 34, 109,   1,   3,   2,   0,   2], dtype=int64), array([122,  70,   2,   0,   1,   1,   1], dtype=int64), array([21, 18,  2,  1,  0,  2,  0], dtype=int64), array([17, 49,  0,  1,  0,  0,  0], dtype=int64), array([39, 63,  2,  3,  2,  1,  2], dtype=int64), array([52, 52,  2,  1,  0,  1,  1], dtype=int64), array([76, 92,  1,  0,  1,  0,  0], dtype=int64), array([51, 38,  2,  1,  0,  1,  1], dtype=int64), array([10, 80,  0,  1,  0,  0,  0], dtype=int64), array([107,  71,   1,   1,   0,   3,   2], dtype=int64), array([80, 17,  1,  1,  3,  2,  2], dtype=int64), array([71,  1,  1,  0,  2,  1,  1], dtype=int64), array([16, 84,  2,  1,  0,  1,  1], dtype=int64), array([100, 110,   1,   2,   1,   0,   1], dtype=int64), array([74, 74,  0,  1,  3,  3,  2], dtype=int64), array([ 46, 129,   1,   0,   0,   1,   0], dtype=int64), array([ 61, 128,   1,   1,   0,   1,   1], dtype=int64), array([ 82, 119,   0,   0,   2,   1,   0], dtype=int64), array([32, 36,  0,  1,  0,  2,  1], dtype=int64), array([124, 130,   1,   2,   0,   2,   0], dtype=int64), array([60, 10,  0,  1,  3,  1,  2], dtype=int64), array([96,  0,  2,  1,  0,  0,  0], dtype=int64), array([90, 62,  1,  1,  1,  0,  1], dtype=int64), array([33, 65,  0,  0,  0,  1,  0], dtype=int64), array([66, 72,  2,  0,  1,  1,  1], dtype=int64), array([ 92, 116,   0,   2,   1,   0,   1], dtype=int64), array([120,  13,   0,   1,   1,   0,   1], dtype=int64), array([110,   6,   0,   1,   0,   0,   0], dtype=int64), array([89, 33,  1,  1,  0,  1,  1], dtype=int64), array([18, 67,  2,  2,  1,  0,  0], dtype=int64), array([85, 97,  2,  2,  2,  1,  1], dtype=int64), array([ 22, 117,   1,   0,   1,   0,   0], dtype=int64), array([ 55, 120,   1,   0,   2,   1,   0], dtype=int64), array([114,  44,   2,   0,   0,   1,   0], dtype=int64), array([58, 41,  1,  1,  0,  2,  0], dtype=int64), array([95, 75,  2,  1,  1,  0,  1], dtype=int64), array([50, 68,  2,  2,  2,  0,  0], dtype=int64), array([ 78, 131,   1,   1,   0,   0,   0], dtype=int64), array([23, 15,  2,  1,  0,  2,  0], dtype=int64), array([115, 100,   2,   2,   0,   3,   2], dtype=int64), array([24, 90,  1,  2,  1,  0,  0], dtype=int64), array([ 6, 79,  2,  0,  2,  1,  1], dtype=int64), array([37, 76,  2,  1,  1,  0,  1], dtype=int64), array([ 2, 82,  2,  0,  3,  0,  2], dtype=int64), array([15, 19,  0,  0,  2,  2,  0], dtype=int64), array([1, 9, 1, 0, 2, 1, 1], dtype=int64), array([119,  12,   2,   2,   3,   1,   2], dtype=int64), array([27, 24,  1,  0,  1,  1,  1], dtype=int64), array([14,  7,  1,  3,  0,  3,  2], dtype=int64), array([128,  39,   1,   0,   1,   0,   0], dtype=int64), array([64,  3,  1,  3,  3,  1,  2], dtype=int64), array([123,  42,   2,   1,   1,   3,   2], dtype=int64), array([  4, 106,   0,   0,   2,   3,   2], dtype=int64), array([20, 51,  0,  1,  1,  0,  1], dtype=int64), array([104,  86,   1,   1,   3,   0,   2], dtype=int64), array([65, 94,  1,  2,  1,  0,  0], dtype=int64), array([98, 21,  2,  0,  3,  3,  2], dtype=int64), arr ...
# Scores: [84.61538461538461, 92.3076923076923, 76.92307692307693, 76.92307692307693, 61.53846153846154, 92.3076923076923, 92.3076923076923, 61.53846153846154, 92.3076923076923, 84.61538461538461]
# Mean Accuracy: 81.5385%
